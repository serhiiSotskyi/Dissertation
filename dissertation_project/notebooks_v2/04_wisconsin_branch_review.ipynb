# %% [markdown]
# # Wisconsin Branch Review
#
# ## Objective
# Summarize the frozen Wisconsin branch exactly as reused in this dissertation.
#
# ## Constraint
# This notebook is read-only. It documents the branch but does not alter or retrain it.

# %%
from pathlib import Path
import json
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[0]
wis_root = PROJECT_ROOT / 'notebook_Wisconsin'
branch_notes = pd.read_csv(PROJECT_ROOT / 'outputs_v2' / 'reports' / 'wisconsin_branch_notes.csv')
label_counts = pd.read_csv(PROJECT_ROOT / 'outputs_v2' / 'reports' / 'wisconsin_label_counts.csv')
branch_notes

# %%
label_counts

# %%
with open(wis_root / 'BreaScope AI.ipynb') as f:
    nb = json.load(f)
for idx in [69, 81]:
    text = ''
    for out in nb['cells'][idx].get('outputs', []):
        if 'text' in out:
            text += ''.join(out['text'])
    print(f'Cell {idx} output:
{text}
')

# %% [markdown]
# ## Interpretation
# The Wisconsin model remains frozen and is referenced as a preserved published branch. Its reported metrics are used for comparison and later synthetic pairing analysis, but the original notebook and artifacts are not modified.
