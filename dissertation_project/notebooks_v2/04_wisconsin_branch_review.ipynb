# %% [markdown]
# # Wisconsin Branch Review
#
# ## Objective
# Summarize the frozen Wisconsin branch without changing it.
#
# ## Constraint
# This notebook reads the published branch and artifacts in a read-only manner. It does not retrain or edit the model.

# %%
from pathlib import Path
import json
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[0]
WISCONSIN_ROOT = PROJECT_ROOT / 'notebook_Wisconsin'
nb_path = WISCONSIN_ROOT / 'BreaScope AI.ipynb'
df = pd.read_csv(WISCONSIN_ROOT / 'brca.csv')
print('rows:', len(df))
print('columns:', len(df.columns))
print(df.head(2).to_string())

# %% [markdown]
# ## Interpretation
# This notebook records the frozen model inputs, outputs, and assumptions for later comparison and packaging. It does not alter the published branch.
