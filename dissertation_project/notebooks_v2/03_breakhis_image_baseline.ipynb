# %% [markdown]
# # BreaKHis Image Baseline
#
# ## Objective
# Train and evaluate a corrected image-only baseline using the patient-level split from Notebook 02.
#
# ## Notes
# This notebook exists to replace the earlier leaked baseline with a defendable result suitable for the dissertation and later transfer to an app.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %% [markdown]
# ## Implementation Placeholder
# The training, evaluation, calibration, and artifact export cells will be filled during implementation.
