# %% [markdown]
# # Scope, Limitations, and Research Questions
#
# ## Objective
# This notebook fixes the dissertation scope and records the exact claims that the project can defend.
#
# ## Core Position
# - The Wisconsin branch is frozen and reused unchanged.
# - The BreaKHis branch is rebuilt with patient-level evaluation.
# - Any multimodal fusion result is based on synthetic label-aligned pairing of independent datasets.
# - The fusion study is exploratory and not clinically representative.
#
# ## Research Questions
# 1. How do the corrected image-only and preserved tabular-only baselines perform independently?
# 2. Can synthetic label-aligned pairing of independent datasets provide a useful exploratory framework for evaluating multimodal fusion?
# 3. How do early fusion and late fusion compare under same-label, random, and repeated-seed pairing controls?
#
# ## Deliverables
# - Defensible image baseline
# - Read-only Wisconsin branch summary
# - Synthetic pairing controls
# - Final figures and dissertation-ready notes

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
DATA_ROOT = PROJECT_ROOT / 'data' / 'dataset_cancer_v1' / 'dataset_cancer_v1'
WISCONSIN_ROOT = PROJECT_ROOT / 'notebook_Wisconsin'
OUTPUT_ROOT = PROJECT_ROOT / 'outputs_v2'
OUTPUT_ROOT.mkdir(exist_ok=True)

print('project root:', PROJECT_ROOT)
print('data root exists:', DATA_ROOT.exists())
print('wisconsin root exists:', WISCONSIN_ROOT.exists())
