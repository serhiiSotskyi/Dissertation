# %% [markdown]
# # Fusion Experiments
#
# ## Objective
# Compare unimodal baselines with synthetic early-fusion and late-fusion experiments under repeated pairing controls.
#
# ## Required Outputs
# - tabular-only baseline
# - image-only baseline
# - same-label early fusion
# - same-label late fusion
# - random-pairing control
# - repeated seed summary

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
OUTPUT_ROOT = PROJECT_ROOT / 'outputs_v2'
OUTPUT_ROOT.mkdir(exist_ok=True)
print('outputs_v2:', OUTPUT_ROOT)

# %% [markdown]
# ## Implementation Placeholder
# The experiment cells will be added during implementation after the image baseline and pairing utilities are finalized.
