# %% [markdown]
# # Results, Figures, and Defense Pack
#
# ## Objective
# Collect the final tables, plots, and written interpretations needed for the dissertation and later demo transfer.
#
# ## Outputs
# - final results tables
# - confusion matrices
# - calibration plots
# - false-negative notes
# - defense-safe interpretations

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
FIG_ROOT = PROJECT_ROOT / 'outputs_v2' / 'figures'
FIG_ROOT.mkdir(parents=True, exist_ok=True)
print(FIG_ROOT)

# %% [markdown]
# ## Interpretation Placeholder
# This notebook will become the final evidence pack used to populate the dissertation template and later app documentation.
