# %% [markdown]
# # Results, Figures, and Defense Pack
#
# ## Objective
# Gather the final tables, plots, and defense-ready interpretation notes for the dissertation write-up.
#
# ## Use
# This notebook is the bridge from experiment outputs into the official dissertation template.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[0]
image_metrics = pd.read_csv(PROJECT_ROOT / 'outputs_v2' / 'metrics' / 'breakhis_patient_metrics.csv')
fusion_summary = pd.read_csv(PROJECT_ROOT / 'outputs_v2' / 'metrics' / 'synthetic_fusion_summary.csv')
image_metrics

# %%
fusion_summary

# %% [markdown]
# ## Defense Notes
# - The Wisconsin branch is frozen and preserved unchanged.
# - The BreaKHis baseline was corrected to remove patient leakage.
# - Synthetic pairing is explicitly artificial and limited.
# - The strongest technical claim is methodological, not clinical.
# - Random-pairing controls are necessary to avoid overstating fusion value.
