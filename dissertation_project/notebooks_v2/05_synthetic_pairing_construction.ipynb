# %% [markdown]
# # Synthetic Pairing Construction
#
# ## Objective
# Create the exploratory synthetic paired dataset used to test fusion strategies.
#
# ## Limitation
# The datasets are independent. Pairing is artificial and uses class labels only.

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT))

from src.pairing import build_same_label_pairs, build_random_pairs, add_consistency_flag

print('Synthetic pairing notebook scaffold ready.')

# %% [markdown]
# ## Controls
# - same-label pairing
# - random pairing
# - repeated pairing seeds
# - optional mismatched-label sanity check
